# %%
import os
import numpy as np
import pandas as pd

mylist = [1, 2, 3, 4, 5]
print(mylist)
# Out:
# [1, 2, 3, 4, 5]

# %%
from PIL import Image
from IPython.display import display

image = Image.open("pictures/Capybara.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=312x312>

# %%
image_arr = np.array(image)
image_arr
# Out:
# array([[[ 44,  45,  49],
#         [ 44,  45,  49],
#         [ 44,  45,  49],
#         ...,
#         [ 56,  62,  65],
#         [ 62,  68,  70],
#         [ 65,  72,  74]],
#
#        [[ 40,  42,  46],
#         [ 40,  42,  46],
#         [ 40,  42,  46],
#         ...,
#         [ 72,  79,  81],
#         [ 67,  74,  76],
#         [ 65,  72,  74]],
#
#        [[ 36,  37,  41],
#         [ 36,  37,  41],
#         [ 36,  37,  41],
#         ...,
#         [ 85,  91,  94],
#         [ 80,  87,  89],
#         [ 78,  84,  87]],
#
#        ...,
#
#        [[201, 189, 175],
#         [208, 196, 182],
#         [162, 153, 138],
#         ...,
#         [231, 219, 207],
#         [189, 177, 165],
#         [182, 170, 158]],
#
#        [[142, 131, 117],
#         [135, 126, 111],
#         [178, 171, 155],
#         ...,
#         [236, 227, 214],
#         [148, 138, 126],
#         [183, 173, 161]],
#
#        [[125, 114,  99],
#         [164, 155, 140],
#         [153, 147, 131],
#         ...,
#         [190, 180, 168],
#         [229, 220, 207],
#         [212, 202, 190]]], shape=(312, 312, 3), dtype=uint8)

# %%
print(image_arr.shape)
print(image_arr.ndim)
# Out:
# (312, 312, 3)
# 3

# %%
image_arr2 = 255 - image_arr
image2 = Image.fromarray(image_arr2)

display(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
image_arr3 = image_arr + 100
image3 = Image.fromarray(image_arr3)

display(image3)
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>
